# %%
def foo(lst):
    lst1 = list(set(lst))
    a = 0
    for i in range(0, len(lst1)):
        for j in range(0, len(lst)):
            if lst1[i] == lst[j]:
                a+=1
        if a == 1:
            return lst1[i]
        a = 0
